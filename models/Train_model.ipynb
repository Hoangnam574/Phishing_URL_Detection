# %%
import pandas as pd
import numpy as np
import re
import unicodedata
import os
import joblib
import xgboost as xgb
from urllib.parse import urlparse
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.pipeline import FeatureUnion
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.base import BaseEstimator, TransformerMixin
from tqdm import tqdm

MAX_FEATURE_URLS = None
CHECKPOINT_DIR = "."

RAW_KEYWORDS = [
    'login', 'secure', 'update', 'verify', 'account', 'bank', 'signin', 'submit',
    'paypal', 'ebay', 'confirm', 'wp', 'mail', 'admin', '88', '365', 'bet', '68', '86',
    'xoso', 'casino', 'bong88', 'banca', '1xbet', 'sex', 'jav', 'xxx', 'phim', 'phim18',
    'phimmoi', '18+', 'hdsex', 'livechat', 'gai goi', 'xo so', 'tructiepbongda',
    'lo de', 'da ga', 'keo bong', 'phim cap 3', 'phim sex', 'phim jav','phimlau','vay tien','giai ngan','789','vay','tien','co bac',
    'sicbo','baccarat','blackjack','sanh game','no hu','tai xiu','xoc dia','game bai','porn','phimmoiz', 'phimhd','phimbo', 'vietsub',
    'tra gop','lo to','da ga','rut tien','hentai','lon','dit','xx','trung thuong','trung iphone','quay so','qua tang',
    'nhan thuong','khuyen mai'
]

def remove_vietnamese_diacritics(text):
    return re.sub(r'\s+', '', ''.join(
        c for c in unicodedata.normalize('NFD', text)
        if unicodedata.category(c) != 'Mn')).lower()

SUSPICIOUS_KEYWORDS = [remove_vietnamese_diacritics(w) for w in RAW_KEYWORDS]

def normalize_url(url):
    return url if url.startswith("http") else "http://" + url

def strip_scheme_www(url):
    parsed = urlparse(normalize_url(url))
    return parsed.netloc.replace("www.", "") + parsed.path + (f"?{parsed.query}" if parsed.query else "")

class URLFeatureExtractor(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None): return self
    def transform(self, X):
        return np.array([
            [
                len(url),
                url.count('.'),
                url.count('-'),
                int(bool(re.search(r'(\d{1,3}\.){3}\d{1,3}', url))),
                sum(1 for word in SUSPICIOUS_KEYWORDS if word in url.lower())
            ]
            for url in tqdm(X, desc="Trích URL feature")
        ])

class TitleFeatureExtractor(BaseEstimator, TransformerMixin):
    def __init__(self, title_mapping=None):
        self.title_mapping = title_mapping or {}
    def fit(self, X, y=None): return self
    def transform(self, X):
        features = []
        for url in X:
            s_url = strip_scheme_www(url)
            title = self.title_mapping.get(s_url, '')
            title_clean = remove_vietnamese_diacritics(title)
            keyword_count = sum(1 for word in SUSPICIOUS_KEYWORDS if word in title_clean)
            features.append([len(title_clean), keyword_count])
        return np.array(features)

def load_datasets():
    print("\nĐang tải và gộp dữ liệu...")

    df1 = pd.read_csv("/kaggle/input/dataset/openphish.csv")[['url']].assign(label=1, title='', source='openphish')
    df2 = pd.read_csv("/kaggle/input/dataset/urlhaus.csv")[['url']].assign(label=1, title='', source='urlhaus')
    df3 = pd.read_csv("/kaggle/input/dataset/phishtank.csv")[['url']].assign(label=1, title='', source='phishtank')
    df4 = pd.read_csv("/kaggle/input/dataset/legit.csv", header=None, names=["index", "domain"])
    df4['url'] = "http://" + df4['domain'].astype(str)
    df4 = df4[['url']].assign(label=0, title='', source='legit')
    df5 = pd.read_csv("/kaggle/input/dataset/phishing_dataset_with_titles (2).csv").fillna({'title': ''})
    df5['source'] = 'phishing_dataset'
    df_black = pd.read_csv("/kaggle/input/dataset/blackbook.csv", header=None, names=['domain'])
    df_black['url'] = "http://" + df_black['domain'].astype(str)
    df_black = df_black[['url']].assign(label=1, title='', source='blackbook')

    df_phish = pd.concat([df1, df2, df3, df5[df5['label'] == 1], df_black], ignore_index=True).drop_duplicates(subset='url')
    df_legit = pd.concat([df4, df5[df5['label'] == 0]], ignore_index=True).drop_duplicates(subset='url')

    min_len = min(len(df_phish), len(df_legit))
    df_phish = df_phish.sample(n=min_len, random_state=42)
    df_legit = df_legit.sample(n=min_len, random_state=42)

    df = pd.concat([df_phish, df_legit], ignore_index=True)
    df['url'] = df['url'].astype(str).apply(strip_scheme_www)
    df['title'] = df['title'].fillna('')

    print(f"Dữ liệu sau cân bằng: {len(df_phish)} URL nguy hiểm, {len(df_legit)} URL an toàn")

    title_mapping = dict(zip(df['url'], df['title']))
    return df[['url', 'label']], title_mapping

def train_model():
    df, title_mapping = load_datasets()
    X = df['url']
    y = df['label']

    print("Trích xuất đặc trưng...")
    vectorizer = TfidfVectorizer(analyzer='char_wb', ngram_range=(3, 5), max_features=5000)
    feature_union = FeatureUnion([
        ('tfidf', vectorizer),
        ('url_custom', URLFeatureExtractor()),
        ('title_custom', TitleFeatureExtractor(title_mapping=title_mapping))
    ])

    if MAX_FEATURE_URLS:
        X = X[:MAX_FEATURE_URLS]
        y = y[:MAX_FEATURE_URLS]

    X_features = feature_union.fit_transform(X)
    X_train, X_test, y_train, y_test = train_test_split(X_features, y, test_size=0.2, random_state=42)
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)

    params = {
        "max_depth": 20,
        "objective": "binary:logistic",
        "tree_method": "hist",
        "device": "cuda",
        "eval_metric": "logloss",
        "verbosity": 3
    }

    total_rounds = 1000
    round_step = 50

    existing_checkpoints = sorted([
        int(f.replace("checkpoint_", "").replace(".json", ""))
        for f in os.listdir(CHECKPOINT_DIR)
        if f.startswith("checkpoint_") and f.endswith(".json")
    ])
    start_round = max(existing_checkpoints) if existing_checkpoints else 0
    model = None

    print(f"Bắt đầu từ vòng {start_round + 1}")
    for i in range(start_round, total_rounds, round_step):
        print(f"Huấn luyện vòng {i+1} đến {i+round_step}...")
        prev_model_path = os.path.join(CHECKPOINT_DIR, f"checkpoint_{i}.json") if i > 0 else None

        model = xgb.train(
            params=params,
            dtrain=dtrain,
            num_boost_round=round_step,
            xgb_model=prev_model_path,
            evals=[(dtest, "eval")],
            early_stopping_rounds=30
        )

        ckpt_path = os.path.join(CHECKPOINT_DIR, f"checkpoint_{i + round_step}.json")
        model.save_model(ckpt_path)
        print(f"Đã lưu checkpoint: {ckpt_path}")

    print("Đánh giá mô hình:")
    y_pred = (model.predict(dtest) > 0.5).astype(int)
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))

    model.save_model("final_model.json")
    joblib.dump(model, "model.pkl")
    joblib.dump(feature_union, "vectorizer.pkl")
    print("Đã lưu model, model.pkl và vectorizer.pkl.")

if __name__ == "__main__":
    train_model()
# Out:
# Đang tải và gộp dữ liệu...
# Dữ liệu sau cân bằng: 1439128 URL nguy hiểm, 1439128 URL an toàn
# Trích xuất đặc trưng...
# Trích URL feature: 100%|██████████| 2878256/2878256 [00:48<00:00, 59413.81it/s]
# Bắt đầu từ vòng 1
# Huấn luyện vòng 1 đến 50...
# [16:37:35] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:37:35] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [16:37:36] INFO: /workspace/src/data/simple_dmatrix.cc:137: Generating new Ellpack page.
# [16:37:36] ======== Monitor (0): SketchContainer ========
# [16:37:36] MakeCuts: 0.005274s, 1 calls @ 5274us
#
# [16:37:36] Prune: 0.004351s, 1 calls @ 4351us
#
# [16:37:36] ScanInput: 0.068288s, 1 calls @ 68288us
#
# [16:37:36] Unique: 0.00392s, 1 calls @ 3920us
#
# [0]	eval-logloss:0.48116
# [1]	eval-logloss:0.36460
# [2]	eval-logloss:0.29059
# [3]	eval-logloss:0.24101
# [4]	eval-logloss:0.20746
# [5]	eval-logloss:0.18356
# [6]	eval-logloss:0.16678
# [7]	eval-logloss:0.15522
# [8]	eval-logloss:0.14659
# [9]	eval-logloss:0.13918
# [10]	eval-logloss:0.13423
# [11]	eval-logloss:0.13108
# [12]	eval-logloss:0.12809
# [13]	eval-logloss:0.12502
# [14]	eval-logloss:0.12304
# [15]	eval-logloss:0.12169
# [16]	eval-logloss:0.12052
# [17]	eval-logloss:0.11880
# [18]	eval-logloss:0.11721
# [19]	eval-logloss:0.11630
# [20]	eval-logloss:0.11555
# [21]	eval-logloss:0.11479
# [22]	eval-logloss:0.11414
# [23]	eval-logloss:0.11321
# [24]	eval-logloss:0.11261
# [25]	eval-logloss:0.11191
# [26]	eval-logloss:0.11131
# [27]	eval-logloss:0.11075
# [28]	eval-logloss:0.10983
# [29]	eval-logloss:0.10941
# [30]	eval-logloss:0.10885
# [31]	eval-logloss:0.10844
# [32]	eval-logloss:0.10797
# [33]	eval-logloss:0.10759
# [34]	eval-logloss:0.10720
# [35]	eval-logloss:0.10682
# [36]	eval-logloss:0.10637
# [37]	eval-logloss:0.10604
# [38]	eval-logloss:0.10577
# [39]	eval-logloss:0.10529
# [40]	eval-logloss:0.10497
# [41]	eval-logloss:0.10470
# [42]	eval-logloss:0.10443
# [43]	eval-logloss:0.10418
# [44]	eval-logloss:0.10386
# [45]	eval-logloss:0.10362
# [46]	eval-logloss:0.10319
# [47]	eval-logloss:0.10292
# [48]	eval-logloss:0.10262
# [49]	eval-logloss:0.10235
# [16:39:48] ======== Monitor (0): Learner ========
# [16:39:48] Configure: 0s, 1 calls @ 0us
#
# [16:39:48] EvalOneIter: 0.664579s, 50 calls @ 664579us
#
# [16:39:48] GetGradient: 0.422474s, 50 calls @ 422474us
#
# [16:39:48] PredictRaw: 0.002019s, 50 calls @ 2019us
#
# [16:39:48] UpdateOneIter: 131.613s, 50 calls @ 131613114us
#
# [16:39:48] ======== Monitor (0): GBTree ========
# [16:39:48] BoostNewTrees: 131.053s, 50 calls @ 131052711us
#
# [16:39:48] CommitModel: 6.6e-05s, 50 calls @ 66us
#
# [16:39:48] ======== Device 0 Memory Allocations:  ========
# [16:39:48] Peak memory usage: 9414MiB
# [16:39:48] Number of allocations: 13560
# [16:39:48] ======== Monitor (0): updater_gpu_hist ========
# [16:39:48] InitData: 0.00434s, 50 calls @ 4340us
#
# [16:39:48] InitDataOnce: 0.004328s, 1 calls @ 4328us
#
# [16:39:48] Update: 130.72s, 50 calls @ 130720456us
#
# [16:39:48] UpdatePredictionCache: 0.331418s, 50 calls @ 331418us
#
# [16:39:48] ======== Monitor (0): gradient_based_sampler ========
# [16:39:48] Sample: 1.01557s, 50 calls @ 1015575us
#
# [16:39:48] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:39:48] AllReduce: 0.009607s, 28143 calls @ 9607us
#
# [16:39:48] BuildHist: 1.28578s, 1675 calls @ 1285781us
#
# [16:39:48] EvaluateSplits: 117.238s, 1675 calls @ 117237736us
#
# [16:39:48] FinalisePosition: 0.030057s, 50 calls @ 30057us
#
# [16:39:48] InitRoot: 5.27111s, 50 calls @ 5271108us
#
# [16:39:48] Reset: 1.06337s, 50 calls @ 1063370us
#
# [16:39:48] UpdatePosition: 5.79108s, 1675 calls @ 5791079us
#
# [16:39:48] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:39:48] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_50.json
# Huấn luyện vòng 51 đến 100...
# [16:39:48] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:39:48] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [0]	eval-logloss:0.10207
# [1]	eval-logloss:0.10178
# [2]	eval-logloss:0.10150
# [3]	eval-logloss:0.10128
# [4]	eval-logloss:0.10112
# [5]	eval-logloss:0.10090
# [6]	eval-logloss:0.10064
# [7]	eval-logloss:0.10042
# [8]	eval-logloss:0.10012
# [9]	eval-logloss:0.09994
# [10]	eval-logloss:0.09966
# [11]	eval-logloss:0.09946
# [12]	eval-logloss:0.09925
# [13]	eval-logloss:0.09911
# [14]	eval-logloss:0.09896
# [15]	eval-logloss:0.09881
# [16]	eval-logloss:0.09864
# [17]	eval-logloss:0.09853
# [18]	eval-logloss:0.09826
# [19]	eval-logloss:0.09815
# [20]	eval-logloss:0.09796
# [21]	eval-logloss:0.09779
# [22]	eval-logloss:0.09770
# [23]	eval-logloss:0.09759
# [24]	eval-logloss:0.09734
# [25]	eval-logloss:0.09724
# [26]	eval-logloss:0.09709
# [27]	eval-logloss:0.09695
# [28]	eval-logloss:0.09680
# [29]	eval-logloss:0.09669
# [30]	eval-logloss:0.09656
# [31]	eval-logloss:0.09640
# [32]	eval-logloss:0.09623
# [33]	eval-logloss:0.09610
# [34]	eval-logloss:0.09595
# [35]	eval-logloss:0.09584
# [36]	eval-logloss:0.09573
# [37]	eval-logloss:0.09553
# [38]	eval-logloss:0.09546
# [39]	eval-logloss:0.09534
# [40]	eval-logloss:0.09524
# [41]	eval-logloss:0.09517
# [42]	eval-logloss:0.09504
# [43]	eval-logloss:0.09496
# [44]	eval-logloss:0.09482
# [45]	eval-logloss:0.09476
# [46]	eval-logloss:0.09466
# [47]	eval-logloss:0.09460
# [48]	eval-logloss:0.09448
# [49]	eval-logloss:0.09438
# [16:41:10] ======== Monitor (0): Learner ========
# [16:41:10] Configure: 0.001401s, 1 calls @ 1401us
#
# [16:41:10] EvalOneIter: 0.965096s, 50 calls @ 965096us
#
# [16:41:10] GetGradient: 0.453443s, 50 calls @ 453443us
#
# [16:41:10] PredictRaw: 5.40303s, 50 calls @ 5403033us
#
# [16:41:10] UpdateOneIter: 81.4467s, 50 calls @ 81446727us
#
# [16:41:10] ======== Monitor (0): GBTree ========
# [16:41:10] BoostNewTrees: 75.5813s, 50 calls @ 75581251us
#
# [16:41:10] CommitModel: 6.4e-05s, 50 calls @ 64us
#
# [16:41:10] ======== Device 0 Memory Allocations:  ========
# [16:41:10] Peak memory usage: 9414MiB
# [16:41:10] Number of allocations: 22903
# [16:41:10] ======== Monitor (0): updater_gpu_hist ========
# [16:41:10] InitData: 0.000356s, 50 calls @ 356us
#
# [16:41:10] InitDataOnce: 0.000345s, 1 calls @ 345us
#
# [16:41:10] Update: 75.2784s, 50 calls @ 75278361us
#
# [16:41:10] UpdatePredictionCache: 0.302149s, 50 calls @ 302149us
#
# [16:41:10] ======== Monitor (0): gradient_based_sampler ========
# [16:41:10] Sample: 0.000163s, 50 calls @ 163us
#
# [16:41:10] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:41:10] AllReduce: 0.003496s, 9934 calls @ 3496us
#
# [16:41:10] BuildHist: 0.554061s, 1083 calls @ 554061us
#
# [16:41:10] EvaluateSplits: 63.8903s, 1083 calls @ 63890284us
#
# [16:41:10] FinalisePosition: 0.025126s, 50 calls @ 25126us
#
# [16:41:10] InitRoot: 5.21856s, 50 calls @ 5218555us
#
# [16:41:10] Reset: 0.021823s, 50 calls @ 21823us
#
# [16:41:10] UpdatePosition: 5.54984s, 1083 calls @ 5549842us
#
# [16:41:10] ======== Monitor (0): Learner ========
# [16:41:10] Configure: 0.000953s, 1 calls @ 953us
#
# [16:41:10] ======== Monitor (0): GBTree ========
# [16:41:10] ======== Device 0 Memory Allocations:  ========
# [16:41:10] Peak memory usage: 9414MiB
# [16:41:10] Number of allocations: 22903
# [16:41:10] ======== Monitor (0): updater_gpu_hist ========
# [16:41:10] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:41:10] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_100.json
# Huấn luyện vòng 101 đến 150...
# [16:41:11] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:41:11] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [0]	eval-logloss:0.09430
# [1]	eval-logloss:0.09421
# [2]	eval-logloss:0.09410
# [3]	eval-logloss:0.09399
# [4]	eval-logloss:0.09391
# [5]	eval-logloss:0.09384
# [6]	eval-logloss:0.09373
# [7]	eval-logloss:0.09355
# [8]	eval-logloss:0.09339
# [9]	eval-logloss:0.09334
# [10]	eval-logloss:0.09325
# [11]	eval-logloss:0.09313
# [12]	eval-logloss:0.09304
# [13]	eval-logloss:0.09297
# [14]	eval-logloss:0.09290
# [15]	eval-logloss:0.09273
# [16]	eval-logloss:0.09267
# [17]	eval-logloss:0.09259
# [18]	eval-logloss:0.09254
# [19]	eval-logloss:0.09249
# [20]	eval-logloss:0.09239
# [21]	eval-logloss:0.09234
# [22]	eval-logloss:0.09229
# [23]	eval-logloss:0.09223
# [24]	eval-logloss:0.09211
# [25]	eval-logloss:0.09206
# [26]	eval-logloss:0.09200
# [27]	eval-logloss:0.09188
# [28]	eval-logloss:0.09181
# [29]	eval-logloss:0.09175
# [30]	eval-logloss:0.09172
# [31]	eval-logloss:0.09166
# [32]	eval-logloss:0.09158
# [33]	eval-logloss:0.09150
# [34]	eval-logloss:0.09147
# [35]	eval-logloss:0.09140
# [36]	eval-logloss:0.09136
# [37]	eval-logloss:0.09125
# [38]	eval-logloss:0.09118
# [39]	eval-logloss:0.09106
# [40]	eval-logloss:0.09103
# [41]	eval-logloss:0.09098
# [42]	eval-logloss:0.09095
# [43]	eval-logloss:0.09089
# [44]	eval-logloss:0.09084
# [45]	eval-logloss:0.09075
# [46]	eval-logloss:0.09064
# [47]	eval-logloss:0.09057
# [48]	eval-logloss:0.09053
# [49]	eval-logloss:0.09047
# [16:42:32] ======== Monitor (0): Learner ========
# [16:42:32] Configure: 0.001081s, 1 calls @ 1081us
#
# [16:42:32] EvalOneIter: 1.44346s, 50 calls @ 1443464us
#
# [16:42:32] GetGradient: 0.448089s, 50 calls @ 448089us
#
# [16:42:32] PredictRaw: 10.4217s, 50 calls @ 10421697us
#
# [16:42:32] UpdateOneIter: 80.2921s, 50 calls @ 80292115us
#
# [16:42:32] ======== Monitor (0): GBTree ========
# [16:42:32] BoostNewTrees: 69.4134s, 50 calls @ 69413361us
#
# [16:42:32] CommitModel: 7.1e-05s, 50 calls @ 71us
#
# [16:42:32] ======== Device 0 Memory Allocations:  ========
# [16:42:32] Peak memory usage: 9741MiB
# [16:42:32] Number of allocations: 32111
# [16:42:32] ======== Monitor (0): updater_gpu_hist ========
# [16:42:32] InitData: 0.000359s, 50 calls @ 359us
#
# [16:42:32] InitDataOnce: 0.000346s, 1 calls @ 346us
#
# [16:42:32] Update: 69.1099s, 50 calls @ 69109948us
#
# [16:42:32] UpdatePredictionCache: 0.302701s, 50 calls @ 302701us
#
# [16:42:32] ======== Monitor (0): gradient_based_sampler ========
# [16:42:32] Sample: 0.000173s, 50 calls @ 173us
#
# [16:42:32] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:42:32] AllReduce: 0.003174s, 8605 calls @ 3174us
#
# [16:42:32] BuildHist: 0.463504s, 1061 calls @ 463504us
#
# [16:42:32] EvaluateSplits: 57.7448s, 1061 calls @ 57744789us
#
# [16:42:32] FinalisePosition: 0.024387s, 50 calls @ 24387us
#
# [16:42:32] InitRoot: 5.22165s, 50 calls @ 5221654us
#
# [16:42:32] Reset: 0.021594s, 50 calls @ 21594us
#
# [16:42:32] UpdatePosition: 5.61664s, 1061 calls @ 5616638us
#
# [16:42:32] ======== Monitor (0): Learner ========
# [16:42:32] Configure: 0.000975s, 1 calls @ 975us
#
# [16:42:32] ======== Monitor (0): GBTree ========
# [16:42:32] ======== Device 0 Memory Allocations:  ========
# [16:42:32] Peak memory usage: 9741MiB
# [16:42:32] Number of allocations: 32111
# [16:42:32] ======== Monitor (0): updater_gpu_hist ========
# [16:42:32] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:42:32] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_150.json
# Huấn luyện vòng 151 đến 200...
# [16:42:33] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:42:33] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [0]	eval-logloss:0.09043
# [1]	eval-logloss:0.09040
# [2]	eval-logloss:0.09034
# [3]	eval-logloss:0.09029
# [4]	eval-logloss:0.09020
# [5]	eval-logloss:0.09014
# [6]	eval-logloss:0.09009
# [7]	eval-logloss:0.09004
# [8]	eval-logloss:0.08999
# [9]	eval-logloss:0.08997
# [10]	eval-logloss:0.08992
# [11]	eval-logloss:0.08985
# [12]	eval-logloss:0.08978
# [13]	eval-logloss:0.08974
# [14]	eval-logloss:0.08967
# [15]	eval-logloss:0.08961
# [16]	eval-logloss:0.08957
# [17]	eval-logloss:0.08954
# [18]	eval-logloss:0.08948
# [19]	eval-logloss:0.08941
# [20]	eval-logloss:0.08938
# [21]	eval-logloss:0.08934
# [22]	eval-logloss:0.08927
# [23]	eval-logloss:0.08924
# [24]	eval-logloss:0.08921
# [25]	eval-logloss:0.08912
# [26]	eval-logloss:0.08906
# [27]	eval-logloss:0.08903
# [28]	eval-logloss:0.08900
# [29]	eval-logloss:0.08897
# [30]	eval-logloss:0.08892
# [31]	eval-logloss:0.08888
# [32]	eval-logloss:0.08879
# [33]	eval-logloss:0.08873
# [34]	eval-logloss:0.08870
# [35]	eval-logloss:0.08867
# [36]	eval-logloss:0.08864
# [37]	eval-logloss:0.08862
# [38]	eval-logloss:0.08858
# [39]	eval-logloss:0.08851
# [40]	eval-logloss:0.08848
# [41]	eval-logloss:0.08846
# [42]	eval-logloss:0.08844
# [43]	eval-logloss:0.08841
# [44]	eval-logloss:0.08838
# [45]	eval-logloss:0.08836
# [46]	eval-logloss:0.08834
# [47]	eval-logloss:0.08828
# [48]	eval-logloss:0.08827
# [49]	eval-logloss:0.08825
# [16:43:54] ======== Monitor (0): Learner ========
# [16:43:54] Configure: 0.00112s, 1 calls @ 1120us
#
# [16:43:54] EvalOneIter: 1.92016s, 50 calls @ 1920160us
#
# [16:43:54] GetGradient: 0.42387s, 50 calls @ 423870us
#
# [16:43:54] PredictRaw: 14.8632s, 50 calls @ 14863205us
#
# [16:43:54] UpdateOneIter: 79.236s, 50 calls @ 79235973us
#
# [16:43:54] ======== Monitor (0): GBTree ========
# [16:43:54] BoostNewTrees: 63.9401s, 50 calls @ 63940145us
#
# [16:43:54] CommitModel: 4.8e-05s, 50 calls @ 48us
#
# [16:43:54] ======== Device 0 Memory Allocations:  ========
# [16:43:54] Peak memory usage: 10013MiB
# [16:43:54] Number of allocations: 41104
# [16:43:54] ======== Monitor (0): updater_gpu_hist ========
# [16:43:54] InitData: 0.000366s, 50 calls @ 366us
#
# [16:43:54] InitDataOnce: 0.000354s, 1 calls @ 354us
#
# [16:43:54] Update: 63.6401s, 50 calls @ 63640077us
#
# [16:43:54] UpdatePredictionCache: 0.299295s, 50 calls @ 299295us
#
# [16:43:54] ======== Monitor (0): gradient_based_sampler ========
# [16:43:54] Sample: 0.00018s, 50 calls @ 180us
#
# [16:43:54] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:43:54] AllReduce: 0.002736s, 7024 calls @ 2736us
#
# [16:43:54] BuildHist: 0.319858s, 1026 calls @ 319858us
#
# [16:43:54] EvaluateSplits: 52.5811s, 1026 calls @ 52581105us
#
# [16:43:54] FinalisePosition: 0.024764s, 50 calls @ 24764us
#
# [16:43:54] InitRoot: 5.05856s, 50 calls @ 5058556us
#
# [16:43:54] Reset: 0.021511s, 50 calls @ 21511us
#
# [16:43:54] UpdatePosition: 5.61803s, 1026 calls @ 5618032us
#
# [16:43:54] ======== Monitor (0): Learner ========
# [16:43:54] Configure: 0.000996s, 1 calls @ 996us
#
# [16:43:54] ======== Monitor (0): GBTree ========
# [16:43:54] ======== Device 0 Memory Allocations:  ========
# [16:43:54] Peak memory usage: 10013MiB
# [16:43:54] Number of allocations: 41104
# [16:43:54] ======== Monitor (0): updater_gpu_hist ========
# [16:43:54] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:43:54] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_200.json
# Huấn luyện vòng 201 đến 250...
# [16:43:54] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:43:54] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [0]	eval-logloss:0.08819
# [1]	eval-logloss:0.08816
# [2]	eval-logloss:0.08811
# [3]	eval-logloss:0.08804
# [4]	eval-logloss:0.08797
# [5]	eval-logloss:0.08792
# [6]	eval-logloss:0.08787
# [7]	eval-logloss:0.08785
# [8]	eval-logloss:0.08782
# [9]	eval-logloss:0.08777
# [10]	eval-logloss:0.08775
# [11]	eval-logloss:0.08773
# [12]	eval-logloss:0.08768
# [13]	eval-logloss:0.08765
# [14]	eval-logloss:0.08760
# [15]	eval-logloss:0.08757
# [16]	eval-logloss:0.08755
# [17]	eval-logloss:0.08751
# [18]	eval-logloss:0.08745
# [19]	eval-logloss:0.08741
# [20]	eval-logloss:0.08735
# [21]	eval-logloss:0.08732
# [22]	eval-logloss:0.08731
# [23]	eval-logloss:0.08729
# [24]	eval-logloss:0.08727
# [25]	eval-logloss:0.08725
# [26]	eval-logloss:0.08723
# [27]	eval-logloss:0.08721
# [28]	eval-logloss:0.08720
# [29]	eval-logloss:0.08717
# [30]	eval-logloss:0.08716
# [31]	eval-logloss:0.08713
# [32]	eval-logloss:0.08710
# [33]	eval-logloss:0.08708
# [34]	eval-logloss:0.08707
# [35]	eval-logloss:0.08705
# [36]	eval-logloss:0.08703
# [37]	eval-logloss:0.08698
# [38]	eval-logloss:0.08696
# [39]	eval-logloss:0.08693
# [40]	eval-logloss:0.08691
# [41]	eval-logloss:0.08690
# [42]	eval-logloss:0.08689
# [43]	eval-logloss:0.08688
# [44]	eval-logloss:0.08686
# [45]	eval-logloss:0.08684
# [46]	eval-logloss:0.08682
# [47]	eval-logloss:0.08679
# [48]	eval-logloss:0.08678
# [49]	eval-logloss:0.08676
# [16:45:20] ======== Monitor (0): Learner ========
# [16:45:20] Configure: 0.001093s, 1 calls @ 1093us
#
# [16:45:20] EvalOneIter: 2.39465s, 50 calls @ 2394652us
#
# [16:45:20] GetGradient: 0.444112s, 50 calls @ 444112us
#
# [16:45:20] PredictRaw: 22.0925s, 50 calls @ 22092486us
#
# [16:45:20] UpdateOneIter: 83.4931s, 50 calls @ 83493125us
#
# [16:45:20] ======== Monitor (0): GBTree ========
# [16:45:20] BoostNewTrees: 60.9478s, 50 calls @ 60947847us
#
# [16:45:20] CommitModel: 5.1e-05s, 50 calls @ 51us
#
# [16:45:20] ======== Device 0 Memory Allocations:  ========
# [16:45:20] Peak memory usage: 10013MiB
# [16:45:20] Number of allocations: 49976
# [16:45:20] ======== Monitor (0): updater_gpu_hist ========
# [16:45:20] InitData: 0.000336s, 50 calls @ 336us
#
# [16:45:20] InitDataOnce: 0.000325s, 1 calls @ 325us
#
# [16:45:20] Update: 60.6493s, 50 calls @ 60649290us
#
# [16:45:20] UpdatePredictionCache: 0.297822s, 50 calls @ 297822us
#
# [16:45:20] ======== Monitor (0): gradient_based_sampler ========
# [16:45:20] Sample: 0.000156s, 50 calls @ 156us
#
# [16:45:20] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:45:20] AllReduce: 0.002352s, 6168 calls @ 2352us
#
# [16:45:20] BuildHist: 0.26764s, 1010 calls @ 267640us
#
# [16:45:20] EvaluateSplits: 49.6764s, 1010 calls @ 49676357us
#
# [16:45:20] FinalisePosition: 0.025217s, 50 calls @ 25217us
#
# [16:45:20] InitRoot: 5.05927s, 50 calls @ 5059268us
#
# [16:45:20] Reset: 0.021695s, 50 calls @ 21695us
#
# [16:45:20] UpdatePosition: 5.58408s, 1010 calls @ 5584085us
#
# [16:45:20] ======== Monitor (0): Learner ========
# [16:45:20] Configure: 0.000917s, 1 calls @ 917us
#
# [16:45:20] ======== Monitor (0): GBTree ========
# [16:45:20] ======== Device 0 Memory Allocations:  ========
# [16:45:20] Peak memory usage: 10013MiB
# [16:45:20] Number of allocations: 49976
# [16:45:20] ======== Monitor (0): updater_gpu_hist ========
# [16:45:20] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:45:20] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_250.json
# Huấn luyện vòng 251 đến 300...
# [16:45:21] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:45:21] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [0]	eval-logloss:0.08674
# [1]	eval-logloss:0.08670
# [2]	eval-logloss:0.08669
# [3]	eval-logloss:0.08668
# [4]	eval-logloss:0.08665
# [5]	eval-logloss:0.08663
# [6]	eval-logloss:0.08653
# [7]	eval-logloss:0.08651
# [8]	eval-logloss:0.08648
# [9]	eval-logloss:0.08645
# [10]	eval-logloss:0.08644
# [11]	eval-logloss:0.08642
# [12]	eval-logloss:0.08641
# [13]	eval-logloss:0.08638
# [14]	eval-logloss:0.08636
# [15]	eval-logloss:0.08632
# [16]	eval-logloss:0.08630
# [17]	eval-logloss:0.08627
# [18]	eval-logloss:0.08626
# [19]	eval-logloss:0.08624
# [20]	eval-logloss:0.08622
# [21]	eval-logloss:0.08621
# [22]	eval-logloss:0.08619
# [23]	eval-logloss:0.08616
# [24]	eval-logloss:0.08613
# [25]	eval-logloss:0.08610
# [26]	eval-logloss:0.08608
# [27]	eval-logloss:0.08607
# [28]	eval-logloss:0.08606
# [29]	eval-logloss:0.08604
# [30]	eval-logloss:0.08602
# [31]	eval-logloss:0.08602
# [32]	eval-logloss:0.08600
# [33]	eval-logloss:0.08600
# [34]	eval-logloss:0.08597
# [35]	eval-logloss:0.08596
# [36]	eval-logloss:0.08594
# [37]	eval-logloss:0.08594
# [38]	eval-logloss:0.08590
# [39]	eval-logloss:0.08587
# [40]	eval-logloss:0.08586
# [41]	eval-logloss:0.08585
# [42]	eval-logloss:0.08583
# [43]	eval-logloss:0.08580
# [44]	eval-logloss:0.08577
# [45]	eval-logloss:0.08575
# [46]	eval-logloss:0.08572
# [47]	eval-logloss:0.08571
# [48]	eval-logloss:0.08570
# [49]	eval-logloss:0.08569
# [16:46:54] ======== Monitor (0): Learner ========
# [16:46:54] Configure: 0.001028s, 1 calls @ 1028us
#
# [16:46:54] EvalOneIter: 2.87717s, 50 calls @ 2877168us
#
# [16:46:54] GetGradient: 0.426307s, 50 calls @ 426307us
#
# [16:46:54] PredictRaw: 31.2766s, 50 calls @ 31276561us
#
# [16:46:54] UpdateOneIter: 90.4076s, 50 calls @ 90407567us
#
# [16:46:54] ======== Monitor (0): GBTree ========
# [16:46:54] BoostNewTrees: 58.6956s, 50 calls @ 58695562us
#
# [16:46:54] CommitModel: 5.7e-05s, 50 calls @ 57us
#
# [16:46:54] ======== Device 0 Memory Allocations:  ========
# [16:46:54] Peak memory usage: 10013MiB
# [16:46:54] Number of allocations: 58857
# [16:46:54] ======== Monitor (0): updater_gpu_hist ========
# [16:46:54] InitData: 0.000337s, 50 calls @ 337us
#
# [16:46:54] InitDataOnce: 0.00032s, 1 calls @ 320us
#
# [16:46:54] Update: 58.4016s, 50 calls @ 58401637us
#
# [16:46:54] UpdatePredictionCache: 0.293208s, 50 calls @ 293208us
#
# [16:46:54] ======== Monitor (0): gradient_based_sampler ========
# [16:46:54] Sample: 0.000149s, 50 calls @ 149us
#
# [16:46:54] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:46:54] AllReduce: 0.002293s, 5791 calls @ 2293us
#
# [16:46:54] BuildHist: 0.260378s, 1008 calls @ 260378us
#
# [16:46:54] EvaluateSplits: 47.4059s, 1008 calls @ 47405869us
#
# [16:46:54] FinalisePosition: 0.024291s, 50 calls @ 24291us
#
# [16:46:54] InitRoot: 5.05675s, 50 calls @ 5056755us
#
# [16:46:54] Reset: 0.021651s, 50 calls @ 21651us
#
# [16:46:54] UpdatePosition: 5.61802s, 1008 calls @ 5618023us
#
# [16:46:54] ======== Monitor (0): Learner ========
# [16:46:54] Configure: 0.000997s, 1 calls @ 997us
#
# [16:46:54] ======== Monitor (0): GBTree ========
# [16:46:54] ======== Device 0 Memory Allocations:  ========
# [16:46:54] Peak memory usage: 10013MiB
# [16:46:54] Number of allocations: 58857
# [16:46:54] ======== Monitor (0): updater_gpu_hist ========
# [16:46:54] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:46:54] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_300.json
# Huấn luyện vòng 301 đến 350...
# [16:46:55] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:46:55] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [0]	eval-logloss:0.08568
# [1]	eval-logloss:0.08567
# [2]	eval-logloss:0.08565
# [3]	eval-logloss:0.08563
# [4]	eval-logloss:0.08561
# [5]	eval-logloss:0.08560
# [6]	eval-logloss:0.08551
# [7]	eval-logloss:0.08550
# [8]	eval-logloss:0.08550
# [9]	eval-logloss:0.08549
# [10]	eval-logloss:0.08547
# [11]	eval-logloss:0.08546
# [12]	eval-logloss:0.08544
# [13]	eval-logloss:0.08543
# [14]	eval-logloss:0.08541
# [15]	eval-logloss:0.08536
# [16]	eval-logloss:0.08534
# [17]	eval-logloss:0.08534
# [18]	eval-logloss:0.08533
# [19]	eval-logloss:0.08531
# [20]	eval-logloss:0.08529
# [21]	eval-logloss:0.08527
# [22]	eval-logloss:0.08525
# [23]	eval-logloss:0.08521
# [24]	eval-logloss:0.08521
# [25]	eval-logloss:0.08519
# [26]	eval-logloss:0.08519
# [27]	eval-logloss:0.08517
# [28]	eval-logloss:0.08515
# [29]	eval-logloss:0.08514
# [30]	eval-logloss:0.08513
# [31]	eval-logloss:0.08512
# [32]	eval-logloss:0.08512
# [33]	eval-logloss:0.08511
# [34]	eval-logloss:0.08510
# [35]	eval-logloss:0.08510
# [36]	eval-logloss:0.08509
# [37]	eval-logloss:0.08508
# [38]	eval-logloss:0.08507
# [39]	eval-logloss:0.08506
# [40]	eval-logloss:0.08504
# [41]	eval-logloss:0.08502
# [42]	eval-logloss:0.08500
# [43]	eval-logloss:0.08499
# [44]	eval-logloss:0.08499
# [45]	eval-logloss:0.08498
# [46]	eval-logloss:0.08498
# [47]	eval-logloss:0.08498
# [48]	eval-logloss:0.08495
# [49]	eval-logloss:0.08494
# [16:48:35] ======== Monitor (0): Learner ========
# [16:48:35] Configure: 0.001022s, 1 calls @ 1022us
#
# [16:48:35] EvalOneIter: 3.34932s, 50 calls @ 3349319us
#
# [16:48:35] GetGradient: 0.447609s, 50 calls @ 447609us
#
# [16:48:35] PredictRaw: 42.6137s, 50 calls @ 42613719us
#
# [16:48:35] UpdateOneIter: 97.4297s, 50 calls @ 97429709us
#
# [16:48:35] ======== Monitor (0): GBTree ========
# [16:48:35] BoostNewTrees: 54.3599s, 50 calls @ 54359860us
#
# [16:48:35] CommitModel: 6e-05s, 50 calls @ 60us
#
# [16:48:35] ======== Device 0 Memory Allocations:  ========
# [16:48:35] Peak memory usage: 10200MiB
# [16:48:35] Number of allocations: 67722
# [16:48:35] ======== Monitor (0): updater_gpu_hist ========
# [16:48:35] InitData: 0.00035s, 50 calls @ 350us
#
# [16:48:35] InitDataOnce: 0.000338s, 1 calls @ 338us
#
# [16:48:35] Update: 54.0656s, 50 calls @ 54065614us
#
# [16:48:35] UpdatePredictionCache: 0.293527s, 50 calls @ 293527us
#
# [16:48:35] ======== Monitor (0): gradient_based_sampler ========
# [16:48:35] Sample: 0.000159s, 50 calls @ 159us
#
# [16:48:35] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:48:35] AllReduce: 0.002031s, 4795 calls @ 2031us
#
# [16:48:35] BuildHist: 0.226402s, 1006 calls @ 226402us
#
# [16:48:35] EvaluateSplits: 42.946s, 1006 calls @ 42946007us
#
# [16:48:35] FinalisePosition: 0.02348s, 50 calls @ 23480us
#
# [16:48:35] InitRoot: 5.23693s, 50 calls @ 5236935us
#
# [16:48:35] Reset: 0.021605s, 50 calls @ 21605us
#
# [16:48:35] UpdatePosition: 5.59732s, 1006 calls @ 5597325us
#
# [16:48:35] ======== Monitor (0): Learner ========
# [16:48:35] Configure: 0.000982s, 1 calls @ 982us
#
# [16:48:35] ======== Monitor (0): GBTree ========
# [16:48:35] ======== Device 0 Memory Allocations:  ========
# [16:48:35] Peak memory usage: 10200MiB
# [16:48:35] Number of allocations: 67722
# [16:48:35] ======== Monitor (0): updater_gpu_hist ========
# [16:48:35] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:48:35] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_350.json
# Huấn luyện vòng 351 đến 400...
# [16:48:36] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:48:36] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [0]	eval-logloss:0.08488
# [1]	eval-logloss:0.08485
# [2]	eval-logloss:0.08484
# [3]	eval-logloss:0.08483
# [4]	eval-logloss:0.08481
# [5]	eval-logloss:0.08480
# [6]	eval-logloss:0.08477
# [7]	eval-logloss:0.08475
# [8]	eval-logloss:0.08471
# [9]	eval-logloss:0.08470
# [10]	eval-logloss:0.08468
# [11]	eval-logloss:0.08467
# [12]	eval-logloss:0.08466
# [13]	eval-logloss:0.08465
# [14]	eval-logloss:0.08464
# [15]	eval-logloss:0.08463
# [16]	eval-logloss:0.08462
# [17]	eval-logloss:0.08461
# [18]	eval-logloss:0.08461
# [19]	eval-logloss:0.08460
# [20]	eval-logloss:0.08456
# [21]	eval-logloss:0.08454
# [22]	eval-logloss:0.08453
# [23]	eval-logloss:0.08452
# [24]	eval-logloss:0.08451
# [25]	eval-logloss:0.08450
# [26]	eval-logloss:0.08450
# [27]	eval-logloss:0.08448
# [28]	eval-logloss:0.08447
# [29]	eval-logloss:0.08446
# [30]	eval-logloss:0.08445
# [31]	eval-logloss:0.08443
# [32]	eval-logloss:0.08443
# [33]	eval-logloss:0.08442
# [34]	eval-logloss:0.08441
# [35]	eval-logloss:0.08440
# [36]	eval-logloss:0.08440
# [37]	eval-logloss:0.08438
# [38]	eval-logloss:0.08437
# [39]	eval-logloss:0.08435
# [40]	eval-logloss:0.08435
# [41]	eval-logloss:0.08434
# [42]	eval-logloss:0.08433
# [43]	eval-logloss:0.08432
# [44]	eval-logloss:0.08431
# [45]	eval-logloss:0.08430
# [46]	eval-logloss:0.08429
# [47]	eval-logloss:0.08428
# [48]	eval-logloss:0.08427
# [49]	eval-logloss:0.08426
# [16:50:44] ======== Monitor (0): Learner ========
# [16:50:44] Configure: 0.001029s, 1 calls @ 1029us
#
# [16:50:44] EvalOneIter: 3.83668s, 50 calls @ 3836684us
#
# [16:50:44] GetGradient: 0.412195s, 50 calls @ 412195us
#
# [16:50:44] PredictRaw: 67.7333s, 50 calls @ 67733333us
#
# [16:50:44] UpdateOneIter: 124.534s, 50 calls @ 124534127us
#
# [16:50:44] ======== Monitor (0): GBTree ========
# [16:50:44] BoostNewTrees: 56.3795s, 50 calls @ 56379454us
#
# [16:50:44] CommitModel: 5.6e-05s, 50 calls @ 56us
#
# [16:50:44] ======== Device 0 Memory Allocations:  ========
# [16:50:44] Peak memory usage: 10200MiB
# [16:50:44] Number of allocations: 76553
# [16:50:44] ======== Monitor (0): updater_gpu_hist ========
# [16:50:44] InitData: 0.000346s, 50 calls @ 346us
#
# [16:50:44] InitDataOnce: 0.000334s, 1 calls @ 334us
#
# [16:50:44] Update: 56.0852s, 50 calls @ 56085164us
#
# [16:50:44] UpdatePredictionCache: 0.293545s, 50 calls @ 293545us
#
# [16:50:44] ======== Monitor (0): gradient_based_sampler ========
# [16:50:44] Sample: 0.000176s, 50 calls @ 176us
#
# [16:50:44] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:50:44] AllReduce: 0.002082s, 5105 calls @ 2082us
#
# [16:50:44] BuildHist: 0.217557s, 1001 calls @ 217557us
#
# [16:50:44] EvaluateSplits: 44.9553s, 1001 calls @ 44955281us
#
# [16:50:44] FinalisePosition: 0.024981s, 50 calls @ 24981us
#
# [16:50:44] InitRoot: 5.22185s, 50 calls @ 5221848us
#
# [16:50:44] Reset: 0.021669s, 50 calls @ 21669us
#
# [16:50:44] UpdatePosition: 5.62964s, 1001 calls @ 5629642us
#
# [16:50:44] ======== Monitor (0): Learner ========
# [16:50:44] Configure: 0.000942s, 1 calls @ 942us
#
# [16:50:44] ======== Monitor (0): GBTree ========
# [16:50:44] ======== Device 0 Memory Allocations:  ========
# [16:50:44] Peak memory usage: 10200MiB
# [16:50:44] Number of allocations: 76553
# [16:50:44] ======== Monitor (0): updater_gpu_hist ========
# [16:50:44] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:50:44] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_400.json
# Huấn luyện vòng 401 đến 450...
# [16:50:45] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:50:45] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [0]	eval-logloss:0.08425
# [1]	eval-logloss:0.08423
# [2]	eval-logloss:0.08422
# [3]	eval-logloss:0.08421
# [4]	eval-logloss:0.08419
# [5]	eval-logloss:0.08414
# [6]	eval-logloss:0.08413
# [7]	eval-logloss:0.08408
# [8]	eval-logloss:0.08408
# [9]	eval-logloss:0.08408
# [10]	eval-logloss:0.08406
# [11]	eval-logloss:0.08405
# [12]	eval-logloss:0.08405
# [13]	eval-logloss:0.08404
# [14]	eval-logloss:0.08404
# [15]	eval-logloss:0.08404
# [16]	eval-logloss:0.08404
# [17]	eval-logloss:0.08403
# [18]	eval-logloss:0.08402
# [19]	eval-logloss:0.08400
# [20]	eval-logloss:0.08399
# [21]	eval-logloss:0.08398
# [22]	eval-logloss:0.08398
# [23]	eval-logloss:0.08396
# [24]	eval-logloss:0.08396
# [25]	eval-logloss:0.08393
# [26]	eval-logloss:0.08391
# [27]	eval-logloss:0.08391
# [28]	eval-logloss:0.08389
# [29]	eval-logloss:0.08388
# [30]	eval-logloss:0.08386
# [31]	eval-logloss:0.08385
# [32]	eval-logloss:0.08385
# [33]	eval-logloss:0.08383
# [34]	eval-logloss:0.08382
# [35]	eval-logloss:0.08382
# [36]	eval-logloss:0.08381
# [37]	eval-logloss:0.08380
# [38]	eval-logloss:0.08379
# [39]	eval-logloss:0.08378
# [40]	eval-logloss:0.08377
# [41]	eval-logloss:0.08377
# [42]	eval-logloss:0.08375
# [43]	eval-logloss:0.08375
# [44]	eval-logloss:0.08375
# [45]	eval-logloss:0.08375
# [46]	eval-logloss:0.08373
# [47]	eval-logloss:0.08372
# [48]	eval-logloss:0.08371
# [49]	eval-logloss:0.08370
# [16:53:16] ======== Monitor (0): Learner ========
# [16:53:16] Configure: 0.001111s, 1 calls @ 1111us
#
# [16:53:16] EvalOneIter: 4.30822s, 50 calls @ 4308217us
#
# [16:53:16] GetGradient: 0.420405s, 50 calls @ 420405us
#
# [16:53:16] PredictRaw: 91.2394s, 50 calls @ 91239352us
#
# [16:53:16] UpdateOneIter: 147.091s, 50 calls @ 147090635us
#
# [16:53:16] ======== Monitor (0): GBTree ========
# [16:53:16] BoostNewTrees: 55.4223s, 50 calls @ 55422257us
#
# [16:53:16] CommitModel: 5.2e-05s, 50 calls @ 52us
#
# [16:53:16] ======== Device 0 Memory Allocations:  ========
# [16:53:16] Peak memory usage: 10200MiB
# [16:53:16] Number of allocations: 85385
# [16:53:16] ======== Monitor (0): updater_gpu_hist ========
# [16:53:16] InitData: 0.000382s, 50 calls @ 382us
#
# [16:53:16] InitDataOnce: 0.00037s, 1 calls @ 370us
#
# [16:53:16] Update: 55.1309s, 50 calls @ 55130929us
#
# [16:53:16] UpdatePredictionCache: 0.290592s, 50 calls @ 290592us
#
# [16:53:16] ======== Monitor (0): gradient_based_sampler ========
# [16:53:16] Sample: 0.000172s, 50 calls @ 172us
#
# [16:53:16] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:53:16] AllReduce: 0.002056s, 4864 calls @ 2056us
#
# [16:53:16] BuildHist: 0.211388s, 1002 calls @ 211388us
#
# [16:53:16] EvaluateSplits: 44.1907s, 1002 calls @ 44190675us
#
# [16:53:16] FinalisePosition: 0.026135s, 50 calls @ 26135us
#
# [16:53:16] InitRoot: 5.05979s, 50 calls @ 5059790us
#
# [16:53:16] Reset: 0.02187s, 50 calls @ 21870us
#
# [16:53:16] UpdatePosition: 5.60667s, 1002 calls @ 5606673us
#
# [16:53:16] ======== Monitor (0): Learner ========
# [16:53:16] Configure: 0.000926s, 1 calls @ 926us
#
# [16:53:16] ======== Monitor (0): GBTree ========
# [16:53:16] ======== Device 0 Memory Allocations:  ========
# [16:53:16] Peak memory usage: 10200MiB
# [16:53:16] Number of allocations: 85385
# [16:53:16] ======== Monitor (0): updater_gpu_hist ========
# [16:53:16] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:53:16] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_450.json
# Huấn luyện vòng 451 đến 500...
# [16:53:17] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:53:17] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [0]	eval-logloss:0.08369
# [1]	eval-logloss:0.08369
# [2]	eval-logloss:0.08368
# [3]	eval-logloss:0.08368
# [4]	eval-logloss:0.08364
# [5]	eval-logloss:0.08363
# [6]	eval-logloss:0.08362
# [7]	eval-logloss:0.08361
# [8]	eval-logloss:0.08361
# [9]	eval-logloss:0.08360
# [10]	eval-logloss:0.08358
# [11]	eval-logloss:0.08358
# [12]	eval-logloss:0.08356
# [13]	eval-logloss:0.08355
# [14]	eval-logloss:0.08354
# [15]	eval-logloss:0.08353
# [16]	eval-logloss:0.08352
# [17]	eval-logloss:0.08352
# [18]	eval-logloss:0.08352
# [19]	eval-logloss:0.08351
# [20]	eval-logloss:0.08350
# [21]	eval-logloss:0.08349
# [22]	eval-logloss:0.08349
# [23]	eval-logloss:0.08349
# [24]	eval-logloss:0.08348
# [25]	eval-logloss:0.08348
# [26]	eval-logloss:0.08348
# [27]	eval-logloss:0.08347
# [28]	eval-logloss:0.08347
# [29]	eval-logloss:0.08345
# [30]	eval-logloss:0.08345
# [31]	eval-logloss:0.08344
# [32]	eval-logloss:0.08344
# [33]	eval-logloss:0.08343
# [34]	eval-logloss:0.08343
# [35]	eval-logloss:0.08342
# [36]	eval-logloss:0.08341
# [37]	eval-logloss:0.08340
# [38]	eval-logloss:0.08339
# [39]	eval-logloss:0.08339
# [40]	eval-logloss:0.08338
# [41]	eval-logloss:0.08336
# [42]	eval-logloss:0.08335
# [43]	eval-logloss:0.08335
# [44]	eval-logloss:0.08330
# [45]	eval-logloss:0.08329
# [46]	eval-logloss:0.08325
# [47]	eval-logloss:0.08324
# [48]	eval-logloss:0.08324
# [49]	eval-logloss:0.08323
# [16:56:11] ======== Monitor (0): Learner ========
# [16:56:11] Configure: 0.001076s, 1 calls @ 1076us
#
# [16:56:11] EvalOneIter: 4.79047s, 50 calls @ 4790469us
#
# [16:56:11] GetGradient: 0.411642s, 50 calls @ 411642us
#
# [16:56:11] PredictRaw: 110.121s, 50 calls @ 110121014us
#
# [16:56:11] UpdateOneIter: 168.755s, 50 calls @ 168755331us
#
# [16:56:11] ======== Monitor (0): GBTree ========
# [16:56:11] BoostNewTrees: 58.2139s, 50 calls @ 58213881us
#
# [16:56:11] CommitModel: 6.3e-05s, 50 calls @ 63us
#
# [16:56:11] ======== Device 0 Memory Allocations:  ========
# [16:56:11] Peak memory usage: 10200MiB
# [16:56:11] Number of allocations: 94242
# [16:56:11] ======== Monitor (0): updater_gpu_hist ========
# [16:56:11] InitData: 0.000369s, 50 calls @ 369us
#
# [16:56:11] InitDataOnce: 0.00035s, 1 calls @ 350us
#
# [16:56:11] Update: 57.9172s, 50 calls @ 57917228us
#
# [16:56:11] UpdatePredictionCache: 0.295904s, 50 calls @ 295904us
#
# [16:56:11] ======== Monitor (0): gradient_based_sampler ========
# [16:56:11] Sample: 0.000162s, 50 calls @ 162us
#
# [16:56:11] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:56:11] AllReduce: 0.002165s, 5260 calls @ 2165us
#
# [16:56:11] BuildHist: 0.234028s, 1005 calls @ 234028us
#
# [16:56:11] EvaluateSplits: 46.774s, 1005 calls @ 46773952us
#
# [16:56:11] FinalisePosition: 0.025091s, 50 calls @ 25091us
#
# [16:56:11] InitRoot: 5.20392s, 50 calls @ 5203917us
#
# [16:56:11] Reset: 0.021786s, 50 calls @ 21786us
#
# [16:56:11] UpdatePosition: 5.64413s, 1005 calls @ 5644130us
#
# [16:56:11] ======== Monitor (0): Learner ========
# [16:56:11] Configure: 0.000926s, 1 calls @ 926us
#
# [16:56:11] ======== Monitor (0): GBTree ========
# [16:56:11] ======== Device 0 Memory Allocations:  ========
# [16:56:11] Peak memory usage: 10200MiB
# [16:56:11] Number of allocations: 94242
# [16:56:11] ======== Monitor (0): updater_gpu_hist ========
# [16:56:11] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:56:11] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_500.json
# Huấn luyện vòng 501 đến 550...
# [16:56:11] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:56:11] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [0]	eval-logloss:0.08322
# [1]	eval-logloss:0.08322
# [2]	eval-logloss:0.08321
# [3]	eval-logloss:0.08321
# [4]	eval-logloss:0.08319
# [5]	eval-logloss:0.08319
# [6]	eval-logloss:0.08318
# [7]	eval-logloss:0.08318
# [8]	eval-logloss:0.08317
# [9]	eval-logloss:0.08316
# [10]	eval-logloss:0.08316
# [11]	eval-logloss:0.08316
# [12]	eval-logloss:0.08316
# [13]	eval-logloss:0.08316
# [14]	eval-logloss:0.08316
# [15]	eval-logloss:0.08315
# [16]	eval-logloss:0.08315
# [17]	eval-logloss:0.08315
# [18]	eval-logloss:0.08314
# [19]	eval-logloss:0.08313
# [20]	eval-logloss:0.08313
# [21]	eval-logloss:0.08312
# [22]	eval-logloss:0.08312
# [23]	eval-logloss:0.08311
# [24]	eval-logloss:0.08311
# [25]	eval-logloss:0.08310
# [26]	eval-logloss:0.08310
# [27]	eval-logloss:0.08309
# [28]	eval-logloss:0.08308
# [29]	eval-logloss:0.08309
# [30]	eval-logloss:0.08308
# [31]	eval-logloss:0.08308
# [32]	eval-logloss:0.08307
# [33]	eval-logloss:0.08306
# [34]	eval-logloss:0.08305
# [35]	eval-logloss:0.08305
# [36]	eval-logloss:0.08304
# [37]	eval-logloss:0.08304
# [38]	eval-logloss:0.08304
# [39]	eval-logloss:0.08305
# [40]	eval-logloss:0.08304
# [41]	eval-logloss:0.08303
# [42]	eval-logloss:0.08303
# [43]	eval-logloss:0.08303
# [44]	eval-logloss:0.08303
# [45]	eval-logloss:0.08302
# [46]	eval-logloss:0.08302
# [47]	eval-logloss:0.08301
# [48]	eval-logloss:0.08301
# [49]	eval-logloss:0.08301
# [16:59:17] ======== Monitor (0): Learner ========
# [16:59:17] Configure: 0.001064s, 1 calls @ 1064us
#
# [16:59:17] EvalOneIter: 5.27849s, 50 calls @ 5278488us
#
# [16:59:17] GetGradient: 0.442288s, 50 calls @ 442288us
#
# [16:59:17] PredictRaw: 130.764s, 50 calls @ 130764211us
#
# [16:59:17] UpdateOneIter: 180.795s, 50 calls @ 180795197us
#
# [16:59:17] ======== Monitor (0): GBTree ========
# [16:59:17] BoostNewTrees: 49.58s, 50 calls @ 49580037us
#
# [16:59:17] CommitModel: 6.1e-05s, 50 calls @ 61us
#
# [16:59:17] ======== Device 0 Memory Allocations:  ========
# [16:59:17] Peak memory usage: 10200MiB
# [16:59:17] Number of allocations: 103066
# [16:59:17] ======== Monitor (0): updater_gpu_hist ========
# [16:59:17] InitData: 0.00035s, 50 calls @ 350us
#
# [16:59:17] InitDataOnce: 0.000339s, 1 calls @ 339us
#
# [16:59:17] Update: 49.2903s, 50 calls @ 49290301us
#
# [16:59:17] UpdatePredictionCache: 0.289007s, 50 calls @ 289007us
#
# [16:59:17] ======== Monitor (0): gradient_based_sampler ========
# [16:59:17] Sample: 0.00019s, 50 calls @ 190us
#
# [16:59:17] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:59:17] AllReduce: 0.001734s, 4013 calls @ 1734us
#
# [16:59:17] BuildHist: 0.190871s, 1000 calls @ 190871us
#
# [16:59:17] EvaluateSplits: 38.1926s, 1000 calls @ 38192551us
#
# [16:59:17] FinalisePosition: 0.024238s, 50 calls @ 24238us
#
# [16:59:17] InitRoot: 5.22278s, 50 calls @ 5222776us
#
# [16:59:17] Reset: 0.021756s, 50 calls @ 21756us
#
# [16:59:17] UpdatePosition: 5.62497s, 1000 calls @ 5624965us
#
# [16:59:17] ======== Monitor (0): Learner ========
# [16:59:17] Configure: 0.000913s, 1 calls @ 913us
#
# [16:59:17] ======== Monitor (0): GBTree ========
# [16:59:17] ======== Device 0 Memory Allocations:  ========
# [16:59:17] Peak memory usage: 10200MiB
# [16:59:17] Number of allocations: 103066
# [16:59:17] ======== Monitor (0): updater_gpu_hist ========
# [16:59:17] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:59:17] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_550.json
# Huấn luyện vòng 551 đến 600...
# [16:59:18] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [16:59:18] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [0]	eval-logloss:0.08301
# [1]	eval-logloss:0.08301
# [2]	eval-logloss:0.08300
# [3]	eval-logloss:0.08300
# [4]	eval-logloss:0.08300
# [5]	eval-logloss:0.08300
# [6]	eval-logloss:0.08299
# [7]	eval-logloss:0.08297
# [8]	eval-logloss:0.08296
# [9]	eval-logloss:0.08295
# [10]	eval-logloss:0.08295
# [11]	eval-logloss:0.08295
# [12]	eval-logloss:0.08294
# [13]	eval-logloss:0.08294
# [14]	eval-logloss:0.08291
# [15]	eval-logloss:0.08291
# [16]	eval-logloss:0.08290
# [17]	eval-logloss:0.08290
# [18]	eval-logloss:0.08289
# [19]	eval-logloss:0.08288
# [20]	eval-logloss:0.08287
# [21]	eval-logloss:0.08286
# [22]	eval-logloss:0.08286
# [23]	eval-logloss:0.08285
# [24]	eval-logloss:0.08285
# [25]	eval-logloss:0.08284
# [26]	eval-logloss:0.08284
# [27]	eval-logloss:0.08283
# [28]	eval-logloss:0.08282
# [29]	eval-logloss:0.08281
# [30]	eval-logloss:0.08281
# [31]	eval-logloss:0.08279
# [32]	eval-logloss:0.08279
# [33]	eval-logloss:0.08279
# [34]	eval-logloss:0.08279
# [35]	eval-logloss:0.08278
# [36]	eval-logloss:0.08277
# [37]	eval-logloss:0.08277
# [38]	eval-logloss:0.08277
# [39]	eval-logloss:0.08275
# [40]	eval-logloss:0.08275
# [41]	eval-logloss:0.08275
# [42]	eval-logloss:0.08275
# [43]	eval-logloss:0.08274
# [44]	eval-logloss:0.08274
# [45]	eval-logloss:0.08273
# [46]	eval-logloss:0.08273
# [47]	eval-logloss:0.08271
# [48]	eval-logloss:0.08271
# [49]	eval-logloss:0.08271
# [17:02:45] ======== Monitor (0): Learner ========
# [17:02:45] Configure: 0.001064s, 1 calls @ 1064us
#
# [17:02:45] EvalOneIter: 5.75112s, 50 calls @ 5751117us
#
# [17:02:45] GetGradient: 0.446763s, 50 calls @ 446763us
#
# [17:02:45] PredictRaw: 145.81s, 50 calls @ 145809666us
#
# [17:02:45] UpdateOneIter: 201.19s, 50 calls @ 201189525us
#
# [17:02:45] ======== Monitor (0): GBTree ========
# [17:02:45] BoostNewTrees: 54.9242s, 50 calls @ 54924178us
#
# [17:02:45] CommitModel: 6e-05s, 50 calls @ 60us
#
# [17:02:45] ======== Device 0 Memory Allocations:  ========
# [17:02:45] Peak memory usage: 10200MiB
# [17:02:45] Number of allocations: 111890
# [17:02:45] ======== Monitor (0): updater_gpu_hist ========
# [17:02:45] InitData: 0.000358s, 50 calls @ 358us
#
# [17:02:45] InitDataOnce: 0.000347s, 1 calls @ 347us
#
# [17:02:45] Update: 54.6314s, 50 calls @ 54631412us
#
# [17:02:45] UpdatePredictionCache: 0.292056s, 50 calls @ 292056us
#
# [17:02:45] ======== Monitor (0): gradient_based_sampler ========
# [17:02:45] Sample: 0.000156s, 50 calls @ 156us
#
# [17:02:45] ======== Monitor (0): GPUHistMakerDevice0 ========
# [17:02:45] AllReduce: 0.00188s, 4404 calls @ 1880us
#
# [17:02:45] BuildHist: 0.198326s, 1000 calls @ 198326us
#
# [17:02:45] EvaluateSplits: 43.5631s, 1000 calls @ 43563132us
#
# [17:02:45] FinalisePosition: 0.025002s, 50 calls @ 25002us
#
# [17:02:45] InitRoot: 5.21194s, 50 calls @ 5211939us
#
# [17:02:45] Reset: 0.021734s, 50 calls @ 21734us
#
# [17:02:45] UpdatePosition: 5.59754s, 1000 calls @ 5597539us
#
# [17:02:45] ======== Monitor (0): Learner ========
# [17:02:45] Configure: 0.000911s, 1 calls @ 911us
#
# [17:02:45] ======== Monitor (0): GBTree ========
# [17:02:45] ======== Device 0 Memory Allocations:  ========
# [17:02:45] Peak memory usage: 10200MiB
# [17:02:45] Number of allocations: 111890
# [17:02:45] ======== Monitor (0): updater_gpu_hist ========
# [17:02:45] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [17:02:45] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_600.json
# Huấn luyện vòng 601 đến 650...
# [17:02:46] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [17:02:46] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [0]	eval-logloss:0.08270
# [1]	eval-logloss:0.08270
# [2]	eval-logloss:0.08270
# [3]	eval-logloss:0.08270
# [4]	eval-logloss:0.08270
# [5]	eval-logloss:0.08269
# [6]	eval-logloss:0.08268
# [7]	eval-logloss:0.08266
# [8]	eval-logloss:0.08266
# [9]	eval-logloss:0.08266
# [10]	eval-logloss:0.08266
# [11]	eval-logloss:0.08266
# [12]	eval-logloss:0.08266
# [13]	eval-logloss:0.08266
# [14]	eval-logloss:0.08265
# [15]	eval-logloss:0.08264
# [16]	eval-logloss:0.08263
# [17]	eval-logloss:0.08263
# [18]	eval-logloss:0.08263
# [19]	eval-logloss:0.08263
# [20]	eval-logloss:0.08262
# [21]	eval-logloss:0.08261
# [22]	eval-logloss:0.08261
# [23]	eval-logloss:0.08260
# [24]	eval-logloss:0.08260
# [25]	eval-logloss:0.08260
# [26]	eval-logloss:0.08260
# [27]	eval-logloss:0.08260
# [28]	eval-logloss:0.08259
# [29]	eval-logloss:0.08259
# [30]	eval-logloss:0.08257
# [31]	eval-logloss:0.08257
# [32]	eval-logloss:0.08257
# [33]	eval-logloss:0.08256
# [34]	eval-logloss:0.08256
# [35]	eval-logloss:0.08255
# [36]	eval-logloss:0.08255
# [37]	eval-logloss:0.08254
# [38]	eval-logloss:0.08254
# [39]	eval-logloss:0.08253
# [40]	eval-logloss:0.08253
# [41]	eval-logloss:0.08252
# [42]	eval-logloss:0.08252
# [43]	eval-logloss:0.08252
# [44]	eval-logloss:0.08248
# [45]	eval-logloss:0.08245
# [46]	eval-logloss:0.08245
# [47]	eval-logloss:0.08244
# [48]	eval-logloss:0.08244
# [49]	eval-logloss:0.08244
# [17:06:26] ======== Monitor (0): Learner ========
# [17:06:26] Configure: 0.001232s, 1 calls @ 1232us
#
# [17:06:26] EvalOneIter: 6.23479s, 50 calls @ 6234794us
#
# [17:06:26] GetGradient: 0.449891s, 50 calls @ 449891us
#
# [17:06:26] PredictRaw: 162.854s, 50 calls @ 162853666us
#
# [17:06:26] UpdateOneIter: 213.358s, 50 calls @ 213358383us
#
# [17:06:26] ======== Monitor (0): GBTree ========
# [17:06:26] BoostNewTrees: 50.046s, 50 calls @ 50046009us
#
# [17:06:26] CommitModel: 5.5e-05s, 50 calls @ 55us
#
# [17:06:26] ======== Device 0 Memory Allocations:  ========
# [17:06:26] Peak memory usage: 10200MiB
# [17:06:26] Number of allocations: 120746
# [17:06:26] ======== Monitor (0): updater_gpu_hist ========
# [17:06:26] InitData: 0.000359s, 50 calls @ 359us
#
# [17:06:26] InitDataOnce: 0.000347s, 1 calls @ 347us
#
# [17:06:26] Update: 49.7536s, 50 calls @ 49753618us
#
# [17:06:26] UpdatePredictionCache: 0.291628s, 50 calls @ 291628us
#
# [17:06:26] ======== Monitor (0): gradient_based_sampler ========
# [17:06:26] Sample: 0.000162s, 50 calls @ 162us
#
# [17:06:26] ======== Monitor (0): GPUHistMakerDevice0 ========
# [17:06:26] AllReduce: 0.001882s, 3997 calls @ 1882us
#
# [17:06:26] BuildHist: 0.20186s, 1005 calls @ 201860us
#
# [17:06:26] EvaluateSplits: 38.7959s, 1005 calls @ 38795855us
#
# [17:06:26] FinalisePosition: 0.025142s, 50 calls @ 25142us
#
# [17:06:26] InitRoot: 5.06089s, 50 calls @ 5060894us
#
# [17:06:26] Reset: 0.021845s, 50 calls @ 21845us
#
# [17:06:26] UpdatePosition: 5.63333s, 1005 calls @ 5633325us
#
# [17:06:26] ======== Monitor (0): Learner ========
# [17:06:26] Configure: 0.000985s, 1 calls @ 985us
#
# [17:06:26] ======== Monitor (0): GBTree ========
# [17:06:26] ======== Device 0 Memory Allocations:  ========
# [17:06:26] Peak memory usage: 10200MiB
# [17:06:26] Number of allocations: 120746
# [17:06:26] ======== Monitor (0): updater_gpu_hist ========
# [17:06:26] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [17:06:26] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_650.json
# Huấn luyện vòng 651 đến 700...
# [17:06:26] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [17:06:26] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [0]	eval-logloss:0.08242
# [1]	eval-logloss:0.08242
# [2]	eval-logloss:0.08241
# [3]	eval-logloss:0.08240
# [4]	eval-logloss:0.08239
# [5]	eval-logloss:0.08239
# [6]	eval-logloss:0.08238
# [7]	eval-logloss:0.08238
# [8]	eval-logloss:0.08238
# [9]	eval-logloss:0.08238
# [10]	eval-logloss:0.08237
# [11]	eval-logloss:0.08237
# [12]	eval-logloss:0.08237
# [13]	eval-logloss:0.08236
# [14]	eval-logloss:0.08236
# [15]	eval-logloss:0.08236
# [16]	eval-logloss:0.08236
# [17]	eval-logloss:0.08235
# [18]	eval-logloss:0.08235
# [19]	eval-logloss:0.08235
# [20]	eval-logloss:0.08235
# [21]	eval-logloss:0.08235
# [22]	eval-logloss:0.08235
# [23]	eval-logloss:0.08233
# [24]	eval-logloss:0.08233
# [25]	eval-logloss:0.08232
# [26]	eval-logloss:0.08232
# [27]	eval-logloss:0.08232
# [28]	eval-logloss:0.08231
# [29]	eval-logloss:0.08229
# [30]	eval-logloss:0.08229
# [31]	eval-logloss:0.08228
# [32]	eval-logloss:0.08228
# [33]	eval-logloss:0.08227
# [34]	eval-logloss:0.08227
# [35]	eval-logloss:0.08226
# [36]	eval-logloss:0.08225
# [37]	eval-logloss:0.08225
# [38]	eval-logloss:0.08224
# [39]	eval-logloss:0.08224
# [40]	eval-logloss:0.08225
# [41]	eval-logloss:0.08225
# [42]	eval-logloss:0.08224
# [43]	eval-logloss:0.08224
# [44]	eval-logloss:0.08224
# [45]	eval-logloss:0.08224
# [46]	eval-logloss:0.08224
# [47]	eval-logloss:0.08223
# [48]	eval-logloss:0.08223
# [49]	eval-logloss:0.08223
# [17:10:22] ======== Monitor (0): Learner ========
# [17:10:22] Configure: 0.001283s, 1 calls @ 1283us
#
# [17:10:22] EvalOneIter: 6.73462s, 50 calls @ 6734624us
#
# [17:10:22] GetGradient: 0.452342s, 50 calls @ 452342us
#
# [17:10:22] PredictRaw: 178.439s, 50 calls @ 178438653us
#
# [17:10:22] UpdateOneIter: 228.361s, 50 calls @ 228361445us
#
# [17:10:22] ======== Monitor (0): GBTree ========
# [17:10:22] BoostNewTrees: 49.4617s, 50 calls @ 49461689us
#
# [17:10:22] CommitModel: 5.5e-05s, 50 calls @ 55us
#
# [17:10:22] ======== Device 0 Memory Allocations:  ========
# [17:10:22] Peak memory usage: 10200MiB
# [17:10:22] Number of allocations: 129569
# [17:10:22] ======== Monitor (0): updater_gpu_hist ========
# [17:10:22] InitData: 0.000393s, 50 calls @ 393us
#
# [17:10:22] InitDataOnce: 0.000381s, 1 calls @ 381us
#
# [17:10:22] Update: 49.1708s, 50 calls @ 49170777us
#
# ...
# [17:18:54] AllReduce: 0.001385s, 2918 calls @ 1385us
#
# [17:18:54] BuildHist: 0.148749s, 1000 calls @ 148749us
#
# [17:18:54] EvaluateSplits: 31.8233s, 1000 calls @ 31823258us
#
# [17:18:54] FinalisePosition: 0.024594s, 50 calls @ 24594us
#
# [17:18:54] InitRoot: 5.0591s, 50 calls @ 5059103us
#
# [17:18:54] Reset: 0.021602s, 50 calls @ 21602us
#
# [17:18:54] UpdatePosition: 5.60524s, 1000 calls @ 5605244us
#
# [17:18:55] ======== Monitor (0): Learner ========
# [17:18:55] Configure: 0.001001s, 1 calls @ 1001us
#
# [17:18:55] ======== Monitor (0): GBTree ========
# [17:18:55] ======== Device 0 Memory Allocations:  ========
# [17:18:55] Peak memory usage: 10200MiB
# [17:18:55] Number of allocations: 147217
# [17:18:55] ======== Monitor (0): updater_gpu_hist ========
# [17:18:55] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [17:18:55] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_800.json
# Huấn luyện vòng 801 đến 850...
# [17:18:55] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [17:18:55] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [0]	eval-logloss:0.08190
# [1]	eval-logloss:0.08190
# [2]	eval-logloss:0.08189
# [3]	eval-logloss:0.08189
# [4]	eval-logloss:0.08189
# [5]	eval-logloss:0.08189
# [6]	eval-logloss:0.08189
# [7]	eval-logloss:0.08189
# [8]	eval-logloss:0.08188
# [9]	eval-logloss:0.08188
# [10]	eval-logloss:0.08188
# [11]	eval-logloss:0.08188
# [12]	eval-logloss:0.08188
# [13]	eval-logloss:0.08188
# [14]	eval-logloss:0.08188
# [15]	eval-logloss:0.08187
# [16]	eval-logloss:0.08187
# [17]	eval-logloss:0.08187
# [18]	eval-logloss:0.08186
# [19]	eval-logloss:0.08187
# [20]	eval-logloss:0.08187
# [21]	eval-logloss:0.08185
# [22]	eval-logloss:0.08185
# [23]	eval-logloss:0.08185
# [24]	eval-logloss:0.08185
# [25]	eval-logloss:0.08185
# [26]	eval-logloss:0.08185
# [27]	eval-logloss:0.08185
# [28]	eval-logloss:0.08186
# [29]	eval-logloss:0.08185
# [30]	eval-logloss:0.08185
# [31]	eval-logloss:0.08184
# [32]	eval-logloss:0.08184
# [33]	eval-logloss:0.08184
# [34]	eval-logloss:0.08184
# [35]	eval-logloss:0.08184
# [36]	eval-logloss:0.08184
# [37]	eval-logloss:0.08184
# [38]	eval-logloss:0.08183
# [39]	eval-logloss:0.08183
# [40]	eval-logloss:0.08182
# [41]	eval-logloss:0.08182
# [42]	eval-logloss:0.08181
# [43]	eval-logloss:0.08181
# [44]	eval-logloss:0.08181
# [45]	eval-logloss:0.08180
# [46]	eval-logloss:0.08181
# [47]	eval-logloss:0.08180
# [48]	eval-logloss:0.08179
# [49]	eval-logloss:0.08179
# [17:23:33] ======== Monitor (0): Learner ========
# [17:23:33] Configure: 0.001191s, 1 calls @ 1191us
#
# [17:23:33] EvalOneIter: 8.17247s, 50 calls @ 8172469us
#
# [17:23:33] GetGradient: 0.409818s, 50 calls @ 409818us
#
# [17:23:33] PredictRaw: 214.72s, 50 calls @ 214719855us
#
# [17:23:33] UpdateOneIter: 269.502s, 50 calls @ 269502020us
#
# [17:23:33] ======== Monitor (0): GBTree ========
# [17:23:33] BoostNewTrees: 54.359s, 50 calls @ 54359024us
#
# [17:23:33] CommitModel: 6.8e-05s, 50 calls @ 68us
#
# [17:23:33] ======== Device 0 Memory Allocations:  ========
# [17:23:33] Peak memory usage: 10200MiB
# [17:23:33] Number of allocations: 156040
# [17:23:33] ======== Monitor (0): updater_gpu_hist ========
# [17:23:33] InitData: 0.000389s, 50 calls @ 389us
#
# [17:23:33] InitDataOnce: 0.000375s, 1 calls @ 375us
#
# [17:23:33] Update: 54.0678s, 50 calls @ 54067845us
#
# [17:23:33] UpdatePredictionCache: 0.290398s, 50 calls @ 290398us
#
# [17:23:33] ======== Monitor (0): gradient_based_sampler ========
# [17:23:33] Sample: 0.000157s, 50 calls @ 157us
#
# [17:23:33] ======== Monitor (0): GPUHistMakerDevice0 ========
# [17:23:33] AllReduce: 0.001791s, 4146 calls @ 1791us
#
# [17:23:33] BuildHist: 0.186141s, 1000 calls @ 186141us
#
# [17:23:33] EvaluateSplits: 43.1152s, 1000 calls @ 43115173us
#
# [17:23:33] FinalisePosition: 0.024719s, 50 calls @ 24719us
#
# [17:23:33] InitRoot: 5.05744s, 50 calls @ 5057440us
#
# [17:23:33] Reset: 0.021748s, 50 calls @ 21748us
#
# [17:23:33] UpdatePosition: 5.64897s, 1000 calls @ 5648968us
#
# [17:23:33] ======== Monitor (0): Learner ========
# [17:23:33] Configure: 0.001024s, 1 calls @ 1024us
#
# [17:23:33] ======== Monitor (0): GBTree ========
# [17:23:33] ======== Device 0 Memory Allocations:  ========
# [17:23:33] Peak memory usage: 10200MiB
# [17:23:33] Number of allocations: 156040
# [17:23:33] ======== Monitor (0): updater_gpu_hist ========
# [17:23:33] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [17:23:33] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_850.json
# Huấn luyện vòng 851 đến 900...
# [17:23:34] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [17:23:34] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [0]	eval-logloss:0.08179
# [1]	eval-logloss:0.08179
# [2]	eval-logloss:0.08179
# [3]	eval-logloss:0.08178
# [4]	eval-logloss:0.08178
# [5]	eval-logloss:0.08178
# [6]	eval-logloss:0.08178
# [7]	eval-logloss:0.08178
# [8]	eval-logloss:0.08178
# [9]	eval-logloss:0.08178
# [10]	eval-logloss:0.08179
# [11]	eval-logloss:0.08178
# [12]	eval-logloss:0.08178
# [13]	eval-logloss:0.08177
# [14]	eval-logloss:0.08177
# [15]	eval-logloss:0.08177
# [16]	eval-logloss:0.08178
# [17]	eval-logloss:0.08177
# [18]	eval-logloss:0.08177
# [19]	eval-logloss:0.08176
# [20]	eval-logloss:0.08176
# [21]	eval-logloss:0.08176
# [22]	eval-logloss:0.08176
# [23]	eval-logloss:0.08176
# [24]	eval-logloss:0.08176
# [25]	eval-logloss:0.08176
# [26]	eval-logloss:0.08176
# [27]	eval-logloss:0.08175
# [28]	eval-logloss:0.08175
# [29]	eval-logloss:0.08173
# [30]	eval-logloss:0.08173
# [31]	eval-logloss:0.08173
# [32]	eval-logloss:0.08173
# [33]	eval-logloss:0.08172
# [34]	eval-logloss:0.08173
# [35]	eval-logloss:0.08173
# [36]	eval-logloss:0.08172
# [37]	eval-logloss:0.08172
# [38]	eval-logloss:0.08172
# [39]	eval-logloss:0.08172
# [40]	eval-logloss:0.08172
# [41]	eval-logloss:0.08171
# [42]	eval-logloss:0.08171
# [43]	eval-logloss:0.08171
# [44]	eval-logloss:0.08170
# [45]	eval-logloss:0.08170
# [46]	eval-logloss:0.08170
# [47]	eval-logloss:0.08170
# [48]	eval-logloss:0.08170
# [49]	eval-logloss:0.08170
# [17:28:25] ======== Monitor (0): Learner ========
# [17:28:25] Configure: 0.001335s, 1 calls @ 1335us
#
# [17:28:25] EvalOneIter: 8.66577s, 50 calls @ 8665771us
#
# [17:28:25] GetGradient: 0.421511s, 50 calls @ 421511us
#
# [17:28:25] PredictRaw: 225.806s, 50 calls @ 225805611us
#
# [17:28:25] UpdateOneIter: 282.432s, 50 calls @ 282431977us
#
# [17:28:25] ======== Monitor (0): GBTree ========
# [17:28:25] BoostNewTrees: 56.196s, 50 calls @ 56195983us
#
# [17:28:25] CommitModel: 7.5e-05s, 50 calls @ 75us
#
# [17:28:25] ======== Device 0 Memory Allocations:  ========
# [17:28:25] Peak memory usage: 10200MiB
# [17:28:25] Number of allocations: 164881
# [17:28:25] ======== Monitor (0): updater_gpu_hist ========
# [17:28:25] InitData: 0.000345s, 50 calls @ 345us
#
# [17:28:25] InitDataOnce: 0.000334s, 1 calls @ 334us
#
# [17:28:25] Update: 55.9043s, 50 calls @ 55904334us
#
# [17:28:25] UpdatePredictionCache: 0.290906s, 50 calls @ 290906us
#
# [17:28:25] ======== Monitor (0): gradient_based_sampler ========
# [17:28:25] Sample: 0.000188s, 50 calls @ 188us
#
# [17:28:25] ======== Monitor (0): GPUHistMakerDevice0 ========
# [17:28:25] AllReduce: 0.00195s, 4597 calls @ 1950us
#
# [17:28:25] BuildHist: 0.225654s, 1002 calls @ 225654us
#
# [17:28:25] EvaluateSplits: 44.7171s, 1002 calls @ 44717086us
#
# [17:28:25] FinalisePosition: 0.024502s, 50 calls @ 24502us
#
# [17:28:25] InitRoot: 5.25645s, 50 calls @ 5256445us
#
# [17:28:25] Reset: 0.021683s, 50 calls @ 21683us
#
# [17:28:25] UpdatePosition: 5.64512s, 1002 calls @ 5645117us
#
# [17:28:25] ======== Monitor (0): Learner ========
# [17:28:25] Configure: 0.000886s, 1 calls @ 886us
#
# [17:28:25] ======== Monitor (0): GBTree ========
# [17:28:25] ======== Device 0 Memory Allocations:  ========
# [17:28:25] Peak memory usage: 10200MiB
# [17:28:25] Number of allocations: 164881
# [17:28:25] ======== Monitor (0): updater_gpu_hist ========
# [17:28:25] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [17:28:25] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_900.json
# Huấn luyện vòng 901 đến 950...
# [17:28:26] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [17:28:26] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [0]	eval-logloss:0.08170
# [1]	eval-logloss:0.08170
# [2]	eval-logloss:0.08170
# [3]	eval-logloss:0.08170
# [4]	eval-logloss:0.08170
# [5]	eval-logloss:0.08169
# [6]	eval-logloss:0.08169
# [7]	eval-logloss:0.08169
# [8]	eval-logloss:0.08168
# [9]	eval-logloss:0.08169
# [10]	eval-logloss:0.08169
# [11]	eval-logloss:0.08168
# [12]	eval-logloss:0.08166
# [13]	eval-logloss:0.08166
# [14]	eval-logloss:0.08166
# [15]	eval-logloss:0.08165
# [16]	eval-logloss:0.08165
# [17]	eval-logloss:0.08165
# [18]	eval-logloss:0.08166
# [19]	eval-logloss:0.08166
# [20]	eval-logloss:0.08166
# [21]	eval-logloss:0.08165
# [22]	eval-logloss:0.08165
# [23]	eval-logloss:0.08165
# [24]	eval-logloss:0.08164
# [25]	eval-logloss:0.08164
# [26]	eval-logloss:0.08164
# [27]	eval-logloss:0.08163
# [28]	eval-logloss:0.08163
# [29]	eval-logloss:0.08163
# [30]	eval-logloss:0.08163
# [31]	eval-logloss:0.08163
# [32]	eval-logloss:0.08163
# [33]	eval-logloss:0.08163
# [34]	eval-logloss:0.08162
# [35]	eval-logloss:0.08163
# [36]	eval-logloss:0.08163
# [37]	eval-logloss:0.08163
# [38]	eval-logloss:0.08162
# [39]	eval-logloss:0.08162
# [40]	eval-logloss:0.08161
# [41]	eval-logloss:0.08161
# [42]	eval-logloss:0.08160
# [43]	eval-logloss:0.08160
# [44]	eval-logloss:0.08160
# [45]	eval-logloss:0.08160
# [46]	eval-logloss:0.08160
# [47]	eval-logloss:0.08160
# [48]	eval-logloss:0.08160
# [49]	eval-logloss:0.08160
# [17:33:22] ======== Monitor (0): Learner ========
# [17:33:22] Configure: 0.001374s, 1 calls @ 1374us
#
# [17:33:22] EvalOneIter: 9.14191s, 50 calls @ 9141910us
#
# [17:33:22] GetGradient: 0.409914s, 50 calls @ 409914us
#
# [17:33:22] PredictRaw: 239.973s, 50 calls @ 239972854us
#
# [17:33:22] UpdateOneIter: 286.203s, 50 calls @ 286203278us
#
# [17:33:22] ======== Monitor (0): GBTree ========
# [17:33:22] BoostNewTrees: 45.812s, 50 calls @ 45811968us
#
# [17:33:22] CommitModel: 8e-05s, 50 calls @ 80us
#
# [17:33:22] ======== Device 0 Memory Allocations:  ========
# [17:33:22] Peak memory usage: 10200MiB
# [17:33:22] Number of allocations: 173705
# [17:33:22] ======== Monitor (0): updater_gpu_hist ========
# [17:33:22] InitData: 0.000365s, 50 calls @ 365us
#
# [17:33:22] InitDataOnce: 0.000353s, 1 calls @ 353us
#
# [17:33:22] Update: 45.5236s, 50 calls @ 45523584us
#
# [17:33:22] UpdatePredictionCache: 0.287671s, 50 calls @ 287671us
#
# [17:33:22] ======== Monitor (0): gradient_based_sampler ========
# [17:33:22] Sample: 0.000153s, 50 calls @ 153us
#
# [17:33:22] ======== Monitor (0): GPUHistMakerDevice0 ========
# [17:33:22] AllReduce: 0.001507s, 3142 calls @ 1507us
#
# [17:33:22] BuildHist: 0.166399s, 1000 calls @ 166399us
#
# [17:33:22] EvaluateSplits: 34.4475s, 1000 calls @ 34447485us
#
# [17:33:22] FinalisePosition: 0.023401s, 50 calls @ 23401us
#
# [17:33:22] InitRoot: 5.22145s, 50 calls @ 5221447us
#
# [17:33:22] Reset: 0.021616s, 50 calls @ 21616us
#
# [17:33:22] UpdatePosition: 5.63077s, 1000 calls @ 5630773us
#
# [17:33:22] ======== Monitor (0): Learner ========
# [17:33:22] Configure: 0.000885s, 1 calls @ 885us
#
# [17:33:22] ======== Monitor (0): GBTree ========
# [17:33:22] ======== Device 0 Memory Allocations:  ========
# [17:33:22] Peak memory usage: 10200MiB
# [17:33:22] Number of allocations: 173705
# [17:33:22] ======== Monitor (0): updater_gpu_hist ========
# [17:33:22] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [17:33:22] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_950.json
# Huấn luyện vòng 951 đến 1000...
# [17:33:23] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [17:33:23] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [0]	eval-logloss:0.08160
# [1]	eval-logloss:0.08160
# [2]	eval-logloss:0.08160
# [3]	eval-logloss:0.08160
# [4]	eval-logloss:0.08160
# [5]	eval-logloss:0.08160
# [6]	eval-logloss:0.08160
# [7]	eval-logloss:0.08160
# [8]	eval-logloss:0.08160
# [9]	eval-logloss:0.08160
# [10]	eval-logloss:0.08160
# [11]	eval-logloss:0.08160
# [12]	eval-logloss:0.08160
# [13]	eval-logloss:0.08159
# [14]	eval-logloss:0.08160
# [15]	eval-logloss:0.08160
# [16]	eval-logloss:0.08159
# [17]	eval-logloss:0.08159
# [18]	eval-logloss:0.08160
# [19]	eval-logloss:0.08159
# [20]	eval-logloss:0.08158
# [21]	eval-logloss:0.08157
# [22]	eval-logloss:0.08156
# [23]	eval-logloss:0.08156
# [24]	eval-logloss:0.08155
# [25]	eval-logloss:0.08155
# [26]	eval-logloss:0.08155
# [27]	eval-logloss:0.08155
# [28]	eval-logloss:0.08155
# [29]	eval-logloss:0.08154
# [30]	eval-logloss:0.08154
# [31]	eval-logloss:0.08154
# [32]	eval-logloss:0.08155
# [33]	eval-logloss:0.08155
# [34]	eval-logloss:0.08156
# [35]	eval-logloss:0.08155
# [36]	eval-logloss:0.08156
# [37]	eval-logloss:0.08156
# [38]	eval-logloss:0.08154
# [39]	eval-logloss:0.08154
# [40]	eval-logloss:0.08154
# [41]	eval-logloss:0.08154
# [42]	eval-logloss:0.08154
# [43]	eval-logloss:0.08155
# [44]	eval-logloss:0.08154
# [45]	eval-logloss:0.08154
# [46]	eval-logloss:0.08152
# [47]	eval-logloss:0.08152
# [48]	eval-logloss:0.08151
# [49]	eval-logloss:0.08151
# [17:38:38] ======== Monitor (0): Learner ========
# [17:38:38] Configure: 0.001026s, 1 calls @ 1026us
#
# [17:38:38] EvalOneIter: 9.63093s, 50 calls @ 9630926us
#
# [17:38:38] GetGradient: 0.410279s, 50 calls @ 410279us
#
# [17:38:38] PredictRaw: 249.965s, 50 calls @ 249965375us
#
# [17:38:38] UpdateOneIter: 306.025s, 50 calls @ 306024829us
#
# [17:38:38] ======== Monitor (0): GBTree ========
# [17:38:38] BoostNewTrees: 55.6406s, 50 calls @ 55640633us
#
# [17:38:38] CommitModel: 7.7e-05s, 50 calls @ 77us
#
# [17:38:38] ======== Device 0 Memory Allocations:  ========
# [17:38:38] Peak memory usage: 10200MiB
# [17:38:38] Number of allocations: 182529
# [17:38:38] ======== Monitor (0): updater_gpu_hist ========
# [17:38:38] InitData: 0.000337s, 50 calls @ 337us
#
# [17:38:38] InitDataOnce: 0.000325s, 1 calls @ 325us
#
# [17:38:38] Update: 55.3484s, 50 calls @ 55348384us
#
# [17:38:38] UpdatePredictionCache: 0.291504s, 50 calls @ 291504us
#
# [17:38:38] ======== Monitor (0): gradient_based_sampler ========
# [17:38:38] Sample: 0.000164s, 50 calls @ 164us
#
# [17:38:38] ======== Monitor (0): GPUHistMakerDevice0 ========
# [17:38:38] AllReduce: 0.001914s, 4312 calls @ 1914us
#
# [17:38:38] BuildHist: 0.205592s, 1000 calls @ 205592us
#
# [17:38:38] EvaluateSplits: 44.181s, 1000 calls @ 44181036us
#
# [17:38:38] FinalisePosition: 0.025175s, 50 calls @ 25175us
#
# [17:38:38] InitRoot: 5.25597s, 50 calls @ 5255967us
#
# [17:38:38] Reset: 0.02189s, 50 calls @ 21890us
#
# [17:38:38] UpdatePosition: 5.64469s, 1000 calls @ 5644690us
#
# [17:38:38] ======== Monitor (0): Learner ========
# [17:38:38] Configure: 0.000912s, 1 calls @ 912us
#
# [17:38:38] ======== Monitor (0): GBTree ========
# [17:38:38] ======== Device 0 Memory Allocations:  ========
# [17:38:38] Peak memory usage: 10200MiB
# [17:38:38] Number of allocations: 182529
# [17:38:38] ======== Monitor (0): updater_gpu_hist ========
# [17:38:38] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 3
# [17:38:38] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# Đã lưu checkpoint: ./checkpoint_1000.json
# Đánh giá mô hình:
# Accuracy: 0.9746131343242098
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98    287760
#            1       0.99      0.96      0.97    287892
#
#     accuracy                           0.97    575652
#    macro avg       0.98      0.97      0.97    575652
# weighted avg       0.98      0.97      0.97    575652
#
# Đã lưu model, model.pkl và vectorizer.pkl.
# [17:39:45] ======== Monitor (0): ellpack_page ========
# [17:39:45] BinningCompression: 0.476409s, 1 calls @ 476409us
#
# [17:39:45] InitCompressedData: 0.014001s, 1 calls @ 14001us
#
# [17:39:45] Quantiles: 0.523058s, 1 calls @ 523058us
#
# [17:39:45] ======== Monitor (0): Learner ========
# [17:39:45] Configure: 0.000988s, 1 calls @ 988us
#
# [17:39:45] ======== Monitor (0): GBTree ========
# [17:39:45] ======== Device 0 Memory Allocations:  ========
# [17:39:45] Peak memory usage: 10200MiB
# [17:39:45] Number of allocations: 182540
# [17:39:45] ======== Monitor (0): updater_gpu_hist ========
